# %% [markdown]
# # 7: Red Neuronal Recurrente LSTM

# %%
import keras
import keras.backend as K
from keras.layers.core import Activation
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, LSTM

# Ignorar las advertencias
import warnings; 
warnings.simplefilter('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn import preprocessing

np.random.seed(1234)  
os.environ['PYTHONHASHSEED'] = '0'

df_train1 = pd.read_csv('df_train1_norm.csv')
df_train3 = pd.read_csv('df_train3_norm.csv')
df_train2 = pd.read_csv('df_train2_norm.csv')
df_train4 = pd.read_csv('df_train4_norm.csv')

df_test1 = pd.read_csv('df_test1_norm.csv')
df_test3 = pd.read_csv('df_test3_norm.csv')
df_test2 = pd.read_csv('df_test2_norm.csv')
df_test4 = pd.read_csv('df_test4_norm.csv')
# Out:
# Using TensorFlow backend.

# %%
df_train1.head()
# Out:
#    Unnamed: 0  unitNumber  cycle  opset_id  sensorMeasure1  sensorMeasure2  \
# 0           0         1.0    1.0         0             0.0       -1.841380
# 1           1         1.0    2.0         1             0.0       -1.149998
# 2           2         1.0    3.0         2             0.0       -0.730978
# 3           3         1.0    4.0         3             0.0       -0.730978
# 4           4         1.0    5.0         4             0.0       -0.689076
#
#    sensorMeasure3  sensorMeasure4  sensorMeasure5  sensorMeasure6  ...    \
# 0       -0.174881       -0.978417            -1.0        0.108606  ...
# 1        0.188062       -0.688356            -1.0        0.108606  ...
# 2       -0.467632       -0.567306            -1.0        0.108606  ...
# 3       -1.357869       -0.833386            -1.0        0.108606  ...
# 4       -1.347597       -0.336628            -1.0        0.108606  ...
#
#    sensorMeasure15  sensorMeasure16  sensorMeasure17  sensorMeasure18  \
# 0        -0.657565             -1.0        -0.847263              0.0
# 1        -0.317332             -1.0        -0.847263              0.0
# 2        -0.704589             -1.0        -0.847263              0.0
# 3        -0.544154             -1.0        -0.847263              0.0
# 4        -0.383719             -1.0        -0.168673              0.0
#
#    sensorMeasure19  sensorMeasure20  sensorMeasure21    rul  rul_norm  label
# 0              0.0         1.437403         1.267169  191.0  0.994792      0
# 1              0.0         1.091890         1.311181  190.0  0.989583      0
# 2              0.0         0.803963         0.551497  189.0  0.984375      0
# 3              0.0         0.400866         0.835661  188.0  0.979167      0
# 4              0.0         0.516036         1.127479  187.0  0.973958      0
#
# [5 rows x 28 columns]

# %%
df_test1.head()
# Out:
#    Unnamed: 0  unitNumber  cycle  opset_id  sensorMeasure1  sensorMeasure2  \
# 0           0         1.0    1.0     649.0             0.0        1.360364
# 1           1         1.0    2.0     590.0             0.0       -1.908688
# 2           2         1.0    3.0      45.0             0.0       -0.037093
# 3           3         1.0    4.0     397.0             0.0       -0.087003
# 4           4         1.0    5.0     247.0             0.0        0.087679
#
#    sensorMeasure3  sensorMeasure4  sensorMeasure5  sensorMeasure6    ...     \
# 0       -0.561570       -0.975963            -1.0        0.175502    ...
# 1        0.070163       -1.393351            -1.0        0.175502    ...
# 2       -0.231709       -0.507711            -1.0        0.175502    ...
# 3       -0.795471        0.252264            -1.0        0.175502    ...
# 4       -0.181730       -0.420942            -1.0        0.175502    ...
#
#    sensorMeasure14  sensorMeasure15  sensorMeasure16  sensorMeasure17  \
# 0        -1.315395        -0.711751             -1.0        -0.462748
# 1         0.066134        -1.570360             -1.0         0.348179
# 2        -0.868632         0.629609             -1.0         0.348179
# 3        -0.593701        -1.177262             -1.0        -1.273674
# 4        -0.923618        -0.784164             -1.0        -2.084601
#
#    sensorMeasure18  sensorMeasure19  sensorMeasure20  sensorMeasure21    rul  \
# 0              0.0              0.0        -0.229966         0.449751  142.0
# 1              0.0              0.0         0.899592         0.665079  141.0
# 2              0.0              0.0         1.323176         0.962492  140.0
# 3              0.0              0.0         0.758397         0.452130  139.0
# 4              0.0              0.0         0.687800         0.919665  138.0
#
#    rul_norm
# 0  0.993007
# 1  0.986014
# 2  0.979021
# 3  0.972028
# 4  0.965035
#
# [5 rows x 27 columns]

# %%
df_train1.drop('Unnamed: 0', axis = 1, inplace=True)
df_train3.drop('Unnamed: 0', axis = 1, inplace=True)
df_train2.drop('Unnamed: 0', axis = 1, inplace=True)
df_train4.drop('Unnamed: 0', axis = 1, inplace=True)

df_test1.drop('Unnamed: 0', axis = 1, inplace=True)
df_test3.drop('Unnamed: 0', axis = 1, inplace=True)
df_test2.drop('Unnamed: 0', axis = 1, inplace=True)
df_test4.drop('Unnamed: 0', axis = 1, inplace=True)

# %%
df_train4.head()
# Out:
#    unitNumber  cycle  opset_id  sensorMeasure1  sensorMeasure2  \
# 0         1.0    1.0      1523       -1.054573       -0.830222
# 1         1.0    2.0      1430        0.692543       -0.840362
# 2         1.0    3.0      2219       -1.054573       -0.850503
# 3         1.0    4.0      1815       -1.054573       -1.028996
# 4         1.0    5.0      3632       -0.391130       -0.858906
#
#    sensorMeasure3  sensorMeasure4  sensorMeasure5  sensorMeasure6  \
# 0       -0.727102       -0.759068       -1.137525       -1.085435
# 1        0.581425        0.325978        0.364013        0.381295
# 2       -0.730125       -0.723181       -1.137525       -1.087290
# 3       -1.158678       -0.714645       -1.137525       -1.085435
# 4       -1.587231       -0.719088       -0.270828       -0.473525
#
#    sensorMeasure7  ...    sensorMeasure15  sensorMeasure16  sensorMeasure17  \
# 0       -1.032105  ...           0.073273        -0.694278        -0.672665
# 1       -1.029170  ...          -0.126106        -0.694278        -0.691356
# 2       -1.026235  ...          -0.024033        -0.694278        -0.710048
# 3       -1.027667  ...           0.078040        -0.694278        -0.747431
# 4       -0.763988  ...           2.180772        -0.694278        -1.607243
#
#    sensorMeasure18  sensorMeasure19  sensorMeasure20  sensorMeasure21    rul  \
# 0        -0.114452         0.418577        -1.069259        -1.073505  320.0
# 1         0.655747         0.418577         0.364182         0.365361  319.0
# 2        -0.114452         0.418577        -0.356708        -1.064078  318.0
# 3        -0.114452         0.418577        -0.535237        -1.064720  317.0
# 4        -2.156853        -2.389313        -0.578631        -0.848748  316.0
#
#    rul_norm  label
# 0  0.996885      0
# 1  0.993769      0
# 2  0.990654      0
# 3  0.987539      0
# 4  0.984424      0
#
# [5 rows x 27 columns]

# %%
df_test4.head()
# Out:
#    unitNumber  cycle  opset_id  sensorMeasure1  sensorMeasure2  \
# 0         1.0    1.0    1914.0        0.702036        0.743370
# 1         1.0    2.0    1609.0       -0.386443       -1.154058
# 2         1.0    3.0    9621.0       -1.052828       -0.803660
# 3         1.0    4.0    4139.0       -1.052828       -0.804737
# 4         1.0    5.0    2003.0       -0.884142       -0.645563
#
#    sensorMeasure3  sensorMeasure4  sensorMeasure5  sensorMeasure6  \
# 0        0.626895        0.257933        0.373856        0.379826
# 1       -1.506155       -1.402996       -0.264667       -0.470364
# 2       -0.709735       -0.773581       -1.136389       -1.082131
# 3       -0.713814       -0.761906       -1.136389       -1.082131
# 4       -0.587275       -0.672739       -0.700528       -0.660733
#
#    sensorMeasure7    ...     sensorMeasure14  sensorMeasure15  \
# 0        0.346807    ...           -0.169114        -0.082979
# 1       -0.737082    ...           -2.374385         2.120752
# 2       -0.991631    ...            0.094183         0.149579
# 3       -0.992385    ...            0.186426         0.100407
# 4       -0.610356    ...           -0.063914         0.024634
#
#    sensorMeasure16  sensorMeasure17  sensorMeasure18  sensorMeasure19  \
# 0        -0.659188         0.544247         0.658809         0.417078
# 1        -0.659188        -1.484405        -2.164472        -2.397634
# 2        -0.659188        -0.687435        -0.114315         0.417078
# 3        -0.659188        -0.687435        -0.114315         0.417078
# 4        -0.659188        -0.506305        -0.038383         0.417078
#
#    sensorMeasure20  sensorMeasure21    rul  rul_norm
# 0         0.355390         0.374624  251.0  0.996032
# 1        -0.651657        -0.658639  250.0  0.992063
# 2        -1.053464        -1.019309  249.0  0.988095
# 3        -1.036258        -1.053009  248.0  0.984127
# 4        -0.602064        -0.598289  247.0  0.980159
#
# [5 rows x 26 columns]

# %% [markdown]
# # Ventana de operación

# %%
# Se seleccionará una ventana de 50 ciclos.
ventana = 50

# %% [markdown]
# # Ajuste de datos para la entrada de las LSTM

# %%
# Función de ajuste de los datos de entrada (samples, time steps, features) 
def gen_sequence(datos, ventana, features):

    # Para una misma unitNumber se colocan los valores de los sensores en una matriz simple (vector).
    
    data_matriz = datos[features].values
    num_elementos = data_matriz.shape[0]
    
    # Por ejemplo, para el id 1 se tienen 192 filas y la ventana es igual a 50
    # por lo que se va a iterar en una lista que que incluya la ventana de la siguiente manera:
    
    # 0 - 50 -> de la row 0 a row 50
    # 1 - 51 -> de la row 1 a row 51
    # 2 - 52 -> de la row 2 a row 52
    # ...
    # 141 - 191 -> from row 141 to 191
    
    for start, stop in zip(range(0, num_elementos-ventana), range(ventana, num_elementos)):
        yield data_matriz[start:stop, :]

# %%
# Se toman los features o atributos.

sequence_cols = ['cycle', 'opset_id'] + ['sensorMeasure' + str(i) for i in range(1,22)]
sequence_cols
# Out:
# ['cycle',
#  'opset_id',
#  'sensorMeasure1',
#  'sensorMeasure2',
#  'sensorMeasure3',
#  'sensorMeasure4',
#  'sensorMeasure5',
#  'sensorMeasure6',
#  'sensorMeasure7',
#  'sensorMeasure8',
#  'sensorMeasure9',
#  'sensorMeasure10',
#  'sensorMeasure11',
#  'sensorMeasure12',
#  'sensorMeasure13',
#  'sensorMeasure14',
#  'sensorMeasure15',
#  'sensorMeasure16',
#  'sensorMeasure17',
#  'sensorMeasure18',
#  'sensorMeasure19',
#  'sensorMeasure20',
#  'sensorMeasure21']

# %%
def secuencias(datos_train):    

    # val es una lista para validar que incluye (192 - 50 = 142) arreglo bi-dimensional (50 rows x 25 columns)
    val=list(gen_sequence(datos_train[datos_train['unitNumber'] == 1], ventana, sequence_cols))
    print(len(val))

    # generador para la secuencia
    seq_gen = (list(gen_sequence(datos_train[datos_train['unitNumber'] == id], ventana, sequence_cols))
               for id in datos_train['unitNumber'].unique())

    # genero la secuencia y lo convierto en un array
    seq_array = np.concatenate(list(seq_gen)).astype(np.float32)
    return seq_array

# %%
seq_array = secuencias(df_train1)
seq_array.shape
# Out:
# 142
# (15631, 50, 23)

# %%
# Función para generar los RUL
def gen_labels(datos, ventana, label):
    
    # Para un unitNumber determinado, se colocan los valores de RUL dentro de una matriz simple (vector).
    
    # Por ejemplo:
    # [[1]
    # [2]
    # [3]
    # [4]
    # [5]
    # ...
    # [200]] 
    
    data_matriz = datos[label].values
    num_elementos = data_matriz.shape[0]

    return data_matriz[ventana:num_elementos, :]

# %%
def labels(datos_train):
    # Obtengo los RUL finales por ventana
    label_gen = [gen_labels(datos_train[datos_train['unitNumber'] == id], ventana, ['rul_norm']) 
                 for id in datos_train['unitNumber'].unique()]

    label_array = np.concatenate(label_gen).astype(np.float32)
    return label_array

# %%
label_array = labels(df_train1)
label_array.shape
# Out:
# (15631, 1)

# %% [markdown]
# # Construcción de la Red Neuronal

# %% [markdown]
# Crearé una función que me permite evaluar el **coeficiente de determinación**

# %%
def r2(y_true, y_pred):
    """Coeficiente de determinación
    """
    SS_res =  K.sum(K.square( y_true - y_pred ))
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %% [markdown]
# **Ahora construiremos la red neuronal.**
# * La primera capa seran neuronas LSTM con 100 unidades seguidas de otra capa LSTM con 50 unidades.
# * Se empleará el *Dropout* luego de cada capa para controlar el **overfitting.**
# * La última capa será una capa *Dense* de salida con una sola unidad donde se empleará la función de activación lineal debido a que es un problema de **regresión**.
#
# <img src="http://oi67.tinypic.com/34sp94x.jpg">

# %%
from keras import regularizers

# %%
numero_features = seq_array.shape[2]
salida = label_array.shape[1]

model = Sequential()

#Primera capa
model.add(LSTM(input_shape=(ventana, numero_features), units=64, return_sequences=True))
model.add(Dropout(0.5))

#Segunda capa
model.add(LSTM(units=32, return_sequences=False))
model.add(Dropout(0.5))

model.add(Dense(units=8))
model.add(Activation("sigmoid"))

model.add(Dense(units=8))
model.add(Activation("sigmoid"))

#Última capa
model.add(Dense(units=salida))
model.add(Activation("linear"))

model.compile(loss='mse', optimizer='rmsprop', metrics=['mae', r2])

print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 50, 64)            22528
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50, 64)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 264
# _________________________________________________________________
# activation_1 (Activation)    (None, 8)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 72
# _________________________________________________________________
# activation_2 (Activation)    (None, 8)                 0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 9
# _________________________________________________________________
# activation_3 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 35,289
# Trainable params: 35,289
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # Ajustando la Red Neuronal

# %%
model_path = 'regression_model.h5'

history = model.fit(seq_array, label_array, epochs=800, batch_size=350, validation_split=0.05, verbose=2,
          callbacks = [keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=0, mode='min'),
                       keras.callbacks.ModelCheckpoint(model_path, monitor='val_loss', save_best_only=True, mode='min', verbose=0),
                       keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, verbose=0, mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)]
          )

# list all data in history
print(history.history.keys())
# Out:
# Train on 14849 samples, validate on 782 samples
# Epoch 1/800
#  - 13s - loss: 2.0614 - mean_absolute_error: 1.4030 - r2: -4.0914e+01 - val_loss: 1.2295 - val_mean_absolute_error: 1.0888 - val_r2: -3.1634e+01
# Epoch 2/800
#  - 9s - loss: 0.9714 - mean_absolute_error: 0.9544 - r2: -1.8775e+01 - val_loss: 0.5986 - val_mean_absolute_error: 0.7446 - val_r2: -1.4537e+01
# Epoch 3/800
#  - 9s - loss: 0.4456 - mean_absolute_error: 0.6230 - r2: -8.0230e+00 - val_loss: 0.2341 - val_mean_absolute_error: 0.4360 - val_r2: -4.8327e+00
# Epoch 4/800
#  - 9s - loss: 0.1570 - mean_absolute_error: 0.3307 - r2: -2.1867e+00 - val_loss: 0.0656 - val_mean_absolute_error: 0.2111 - val_r2: -5.7105e-01
# Epoch 5/800
#  - 9s - loss: 0.0514 - mean_absolute_error: 0.1855 - r2: -3.8940e-02 - val_loss: 0.0295 - val_mean_absolute_error: 0.1499 - val_r2: 0.1791
# Epoch 6/800
#  - 11s - loss: 0.0208 - mean_absolute_error: 0.1180 - r2: 0.5780 - val_loss: 0.0153 - val_mean_absolute_error: 0.0976 - val_r2: 0.6259
# Epoch 7/800
#  - 11s - loss: 0.0133 - mean_absolute_error: 0.0926 - r2: 0.7296 - val_loss: 0.0139 - val_mean_absolute_error: 0.0907 - val_r2: 0.6568
# Epoch 8/800
#  - 11s - loss: 0.0109 - mean_absolute_error: 0.0834 - r2: 0.7786 - val_loss: 0.0129 - val_mean_absolute_error: 0.0959 - val_r2: 0.6779
# Epoch 9/800
#  - 10s - loss: 0.0095 - mean_absolute_error: 0.0776 - r2: 0.8057 - val_loss: 0.0096 - val_mean_absolute_error: 0.0802 - val_r2: 0.7740
# Epoch 10/800
#  - 10s - loss: 0.0085 - mean_absolute_error: 0.0735 - r2: 0.8262 - val_loss: 0.0097 - val_mean_absolute_error: 0.0771 - val_r2: 0.7738
# Epoch 11/800
#  - 10s - loss: 0.0077 - mean_absolute_error: 0.0694 - r2: 0.8443 - val_loss: 0.0090 - val_mean_absolute_error: 0.0740 - val_r2: 0.7948
# Epoch 12/800
#  - 10s - loss: 0.0075 - mean_absolute_error: 0.0685 - r2: 0.8475 - val_loss: 0.0069 - val_mean_absolute_error: 0.0627 - val_r2: 0.8399
# Epoch 13/800
#  - 10s - loss: 0.0068 - mean_absolute_error: 0.0651 - r2: 0.8626 - val_loss: 0.0080 - val_mean_absolute_error: 0.0620 - val_r2: 0.7913
# Epoch 14/800
#  - 10s - loss: 0.0065 - mean_absolute_error: 0.0635 - r2: 0.8687 - val_loss: 0.0061 - val_mean_absolute_error: 0.0562 - val_r2: 0.8481
# Epoch 15/800
#  - 10s - loss: 0.0060 - mean_absolute_error: 0.0611 - r2: 0.8774 - val_loss: 0.0058 - val_mean_absolute_error: 0.0584 - val_r2: 0.8652
# Epoch 16/800
#  - 10s - loss: 0.0059 - mean_absolute_error: 0.0605 - r2: 0.8806 - val_loss: 0.0069 - val_mean_absolute_error: 0.0687 - val_r2: 0.8032
# Epoch 17/800
#  - 10s - loss: 0.0057 - mean_absolute_error: 0.0594 - r2: 0.8849 - val_loss: 0.0057 - val_mean_absolute_error: 0.0581 - val_r2: 0.8698
# Epoch 18/800
#  - 10s - loss: 0.0055 - mean_absolute_error: 0.0585 - r2: 0.8871 - val_loss: 0.0065 - val_mean_absolute_error: 0.0649 - val_r2: 0.8376
# Epoch 19/800
#  - 10s - loss: 0.0053 - mean_absolute_error: 0.0567 - r2: 0.8932 - val_loss: 0.0083 - val_mean_absolute_error: 0.0618 - val_r2: 0.7903
# Epoch 20/800
#  - 10s - loss: 0.0051 - mean_absolute_error: 0.0560 - r2: 0.8954 - val_loss: 0.0044 - val_mean_absolute_error: 0.0503 - val_r2: 0.8915
# Epoch 21/800
#  - 10s - loss: 0.0050 - mean_absolute_error: 0.0550 - r2: 0.8994 - val_loss: 0.0040 - val_mean_absolute_error: 0.0462 - val_r2: 0.9005
# Epoch 22/800
#  - 10s - loss: 0.0049 - mean_absolute_error: 0.0545 - r2: 0.9012 - val_loss: 0.0053 - val_mean_absolute_error: 0.0573 - val_r2: 0.8761
# Epoch 23/800
#  - 10s - loss: 0.0046 - mean_absolute_error: 0.0530 - r2: 0.9059 - val_loss: 0.0065 - val_mean_absolute_error: 0.0576 - val_r2: 0.8367
# Epoch 24/800
#  - 10s - loss: 0.0046 - mean_absolute_error: 0.0528 - r2: 0.9066 - val_loss: 0.0050 - val_mean_absolute_error: 0.0568 - val_r2: 0.8734
# Epoch 25/800
#  - 10s - loss: 0.0044 - mean_absolute_error: 0.0520 - r2: 0.9102 - val_loss: 0.0059 - val_mean_absolute_error: 0.0535 - val_r2: 0.8505
# Epoch 26/800
#  - 10s - loss: 0.0042 - mean_absolute_error: 0.0505 - r2: 0.9145 - val_loss: 0.0042 - val_mean_absolute_error: 0.0500 - val_r2: 0.8936
# Epoch 27/800
#  - 9s - loss: 0.0043 - mean_absolute_error: 0.0514 - r2: 0.9120 - val_loss: 0.0049 - val_mean_absolute_error: 0.0528 - val_r2: 0.8744
# Epoch 28/800
#  - 9s - loss: 0.0041 - mean_absolute_error: 0.0503 - r2: 0.9158 - val_loss: 0.0043 - val_mean_absolute_error: 0.0539 - val_r2: 0.8958
# Epoch 29/800
#  - 9s - loss: 0.0040 - mean_absolute_error: 0.0495 - r2: 0.9194 - val_loss: 0.0054 - val_mean_absolute_error: 0.0585 - val_r2: 0.8599
# Epoch 30/800
#  - 10s - loss: 0.0040 - mean_absolute_error: 0.0492 - r2: 0.9193 - val_loss: 0.0036 - val_mean_absolute_error: 0.0421 - val_r2: 0.9109
# Epoch 31/800
#  - 10s - loss: 0.0038 - mean_absolute_error: 0.0485 - r2: 0.9222 - val_loss: 0.0051 - val_mean_absolute_error: 0.0495 - val_r2: 0.8689
# Epoch 32/800
#  - 10s - loss: 0.0037 - mean_absolute_error: 0.0474 - r2: 0.9255 - val_loss: 0.0042 - val_mean_absolute_error: 0.0469 - val_r2: 0.8955
# Epoch 33/800
#  - 9s - loss: 0.0037 - mean_absolute_error: 0.0473 - r2: 0.9255 - val_loss: 0.0035 - val_mean_absolute_error: 0.0429 - val_r2: 0.9129
# Epoch 34/800
#  - 9s - loss: 0.0035 - mean_absolute_error: 0.0465 - r2: 0.9280 - val_loss: 0.0081 - val_mean_absolute_error: 0.0651 - val_r2: 0.7948
# Epoch 35/800
#  - 10s - loss: 0.0034 - mean_absolute_error: 0.0458 - r2: 0.9299 - val_loss: 0.0056 - val_mean_absolute_error: 0.0550 - val_r2: 0.8550
# Epoch 36/800
#  - 11s - loss: 0.0034 - mean_absolute_error: 0.0455 - r2: 0.9313 - val_loss: 0.0048 - val_mean_absolute_error: 0.0494 - val_r2: 0.8759
# Epoch 37/800
#  - 11s - loss: 0.0033 - mean_absolute_error: 0.0450 - r2: 0.9331 - val_loss: 0.0062 - val_mean_absolute_error: 0.0509 - val_r2: 0.8486
# Epoch 38/800
#  - 10s - loss: 0.0033 - mean_absolute_error: 0.0447 - r2: 0.9334 - val_loss: 0.0057 - val_mean_absolute_error: 0.0645 - val_r2: 0.8519
# Epoch 39/800
#  - 10s - loss: 0.0032 - mean_absolute_error: 0.0441 - r2: 0.9352 - val_loss: 0.0046 - val_mean_absolute_error: 0.0475 - val_r2: 0.8841
# Epoch 40/800
#  - 10s - loss: 0.0031 - mean_absolute_error: 0.0437 - r2: 0.9365 - val_loss: 0.0052 - val_mean_absolute_error: 0.0496 - val_r2: 0.8662
# Epoch 41/800
#  - 10s - loss: 0.0025 - mean_absolute_error: 0.0393 - r2: 0.9484 - val_loss: 0.0034 - val_mean_absolute_error: 0.0402 - val_r2: 0.9157
# Epoch 42/800
#  - 9s - loss: 0.0025 - mean_absolute_error: 0.0388 - r2: 0.9502 - val_loss: 0.0034 - val_mean_absolute_error: 0.0399 - val_r2: 0.9161
# Epoch 43/800
#  - 11s - loss: 0.0024 - mean_absolute_error: 0.0381 - r2: 0.9512 - val_loss: 0.0036 - val_mean_absolute_error: 0.0417 - val_r2: 0.9115
# Epoch 44/800
#  - 12s - loss: 0.0024 - mean_absolute_error: 0.0383 - r2: 0.9508 - val_loss: 0.0034 - val_mean_absolute_error: 0.0402 - val_r2: 0.9162
# Epoch 45/800
#  - 11s - loss: 0.0024 - mean_absolute_error: 0.0383 - r2: 0.9511 - val_loss: 0.0032 - val_mean_absolute_error: 0.0396 - val_r2: 0.9228
# Epoch 46/800
#  - 11s - loss: 0.0024 - mean_absolute_error: 0.0381 - r2: 0.9521 - val_loss: 0.0034 - val_mean_absolute_error: 0.0412 - val_r2: 0.9184
# Epoch 47/800
#  - 11s - loss: 0.0023 - mean_absolute_error: 0.0373 - r2: 0.9537 - val_loss: 0.0034 - val_mean_absolute_error: 0.0413 - val_r2: 0.9159
# Epoch 48/800
#  - 12s - loss: 0.0023 - mean_absolute_error: 0.0377 - r2: 0.9528 - val_loss: 0.0034 - val_mean_absolute_error: 0.0410 - val_r2: 0.9163
# Epoch 49/800
#  - 11s - loss: 0.0023 - mean_absolute_error: 0.0376 - r2: 0.9527 - val_loss: 0.0033 - val_mean_absolute_error: 0.0407 - val_r2: 0.9203
# Epoch 50/800
#  - 11s - loss: 0.0023 - mean_absolute_error: 0.0373 - r2: 0.9540 - val_loss: 0.0032 - val_mean_absolute_error: 0.0400 - val_r2: 0.9230
# Epoch 51/800
#  - 10s - loss: 0.0023 - mean_absolute_error: 0.0376 - r2: 0.9531 - val_loss: 0.0033 - val_mean_absolute_error: 0.0399 - val_r2: 0.9207
# Epoch 52/800
#  - 10s - loss: 0.0023 - mean_absolute_error: 0.0375 - r2: 0.9535 - val_loss: 0.0034 - val_mean_absolute_error: 0.0402 - val_r2: 0.9179
# Epoch 53/800
#  - 10s - loss: 0.0023 - mean_absolute_error: 0.0374 - r2: 0.9536 - val_loss: 0.0034 - val_mean_absolute_error: 0.0415 - val_r2: 0.9166
# Epoch 54/800
#  - 10s - loss: 0.0022 - mean_absolute_error: 0.0371 - r2: 0.9546 - val_loss: 0.0034 - val_mean_absolute_error: 0.0405 - val_r2: 0.9182
# Epoch 55/800
#  - 10s - loss: 0.0022 - mean_absolute_error: 0.0369 - r2: 0.9548 - val_loss: 0.0035 - val_mean_absolute_error: 0.0394 - val_r2: 0.9141
# dict_keys(['val_loss', 'val_mean_absolute_error', 'val_r2', 'loss', 'mean_absolute_error', 'r2', 'lr'])

# %% [markdown]
# # Graficos

# %%
# Historial para el R^2
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['r2'])
plt.plot(history.history['val_r2'])
plt.title('Coeficiente de determinación R^2 para el entrenamiento y la validación')
plt.ylabel('R^2')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig("model_r2.png")

# Historial para el MAE
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model MAE')
plt.ylabel('MAE')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Historial para el Loss
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig("model_regression_loss.png")

# Metricas de entrenamiento
scores = model.evaluate(seq_array, label_array, verbose=1, batch_size=200)
print('\nMAE: {}'.format(scores[1]))
print('\nR^2: {}'.format(scores[2]))

y_pred = model.predict(seq_array, verbose=1, batch_size=200)
y_real = label_array

test_set = pd.DataFrame(y_pred)
# Out:
# 15631/15631 [==============================] - 3s 191us/step
#
# MAE: 0.02802186960689416
#
# R^2: 0.9665238817764193
# 15631/15631 [==============================] - 3s 210us/step

# %%
test_set.head()
# Out:
#           0
# 0  0.732551
# 1  0.732899
# 2  0.733643
# 3  0.733042
# 4  0.733010

# %% [markdown]
# # Probando la Red Neuronal con los datos de prueba.

# %%
def probando_test(datos):
    # Se seleccionará la ultima ventana para cada máquina de los datos de prueba.

    seq_array_test_last = [datos[datos['unitNumber']==id][sequence_cols].values[-ventana:] 
                           for id in datos['unitNumber'].unique() if 
                           len(datos[datos['unitNumber']==id]) >= ventana]

    seq_array_test_last = np.asarray(seq_array_test_last).astype(np.float32)

    print("seq_array_test_last")
    print(seq_array_test_last.shape)

    # De manera similar tomaremos los RUL

    y_mask = [len(datos[datos['unitNumber']==id]) >= ventana for id in datos['unitNumber'].unique()]
    label_array_test_last = datos.groupby('unitNumber')['rul_norm'].nth(-1)[y_mask].values
    label_array_test_last = label_array_test_last.reshape(label_array_test_last.shape[0],1).astype(np.float32)

    print("label_array_test_last")
    print(label_array_test_last.shape)

    # Se carga el mejor modelo de iteración y se usa.
    if os.path.isfile(model_path):
        estimator = load_model(model_path, custom_objects={'r2': r2})

        # metricas de prueba
        scores_test = estimator.evaluate(seq_array_test_last, label_array_test_last, verbose=2)
        print('\nMAE: {}'.format(scores_test[1]))
        print('\nR^2: {}'.format(scores_test[2]))

        y_pred_test = estimator.predict(seq_array_test_last)
        y_true_test = label_array_test_last

        test_set_1 = pd.DataFrame(y_pred_test)

        # Se grafica en color azul los datos predichos y en color verde
        # los dastos reales para verficiar la exactitud del modelo.

        fig_verify = plt.figure(figsize=(10, 5))
        plt.plot(y_pred_test, color="blue")
        plt.plot(y_true_test, color="green")
        plt.title('Predicción')
        plt.ylabel('Remaining Useful Life (RUL)')
        plt.xlabel('Cycles')
        plt.legend(['Predicho', 'Real'], loc='upper left')
        plt.show()
        fig_verify.savefig("model_regression_verify.png")
        
        return label_array_test_last, test_set_1

# %%
label_array_test_last, test_set_1 = probando_test(df_test1)
# Out:
# seq_array_test_last
# (93, 50, 23)
# label_array_test_last
# (93, 1)
#
# MAE: 0.08307775326313512
#
# R^2: 0.7314704252827552

# %%
print('\nValores reales:')
print(label_array_test_last.T)
# Out:
# Valores reales:
# [[0.35384616 0.43617022 0.4814815  0.47474748 0.3625498  0.36398467
#   0.6686747  0.33333334 0.5388889  0.36363637 0.3275862  0.5220126
#   0.42639595 0.23255815 0.17391305 0.3918919  0.08       0.27804878
#   0.46502057 0.09708738 0.61025643 0.32038835 0.38039216 0.3448276
#   0.44573644 0.03921569 0.24870466 0.67948717 0.03333334 0.05263158
#   0.13103448 0.14788732 0.2857143  0.17391305 0.12765957 0.06024097
#   0.25541127 0.66871166 0.42857143 0.24352331 0.64903843 0.5411765
#   0.06481481 0.5163399  0.44186047 0.13302752 0.1368421  0.44495413
#   0.548      0.09933775 0.39163497 0.17370892 0.5480769  0.4048583
#   0.11666667 0.18881118 0.3171806  0.14285715 0.6432161  0.08695652
#   0.5202703  0.04102564 0.69142854 0.3821138  0.6344086  0.2762431
#   0.5390946  0.47908744 0.56218904 0.04651163 0.1734694  0.5977654
#   0.38414633 0.40358743 0.0361991  0.05263158 0.65238094 0.2521739
#   0.44723618 0.6744186  0.6284153  0.4345048  0.16091955 0.13970588
#   0.11764706 0.25835866 0.2925532  0.58986175 0.5854701  0.37962964
#   0.32777777 0.54672897 0.09174312]]

# %%
print('\nValores predichos:')
test_set_1.T
# Out:
# Valores predichos:
#          0         1         2         3         4         5         6   \
# 0  0.158006  0.340637  0.367981  0.468575  0.354113  0.250953  0.697891
#
#          7         8         9    ...          83        84        85  \
# 0  0.227141  0.497714  0.240106   ...    0.037876  0.036808  0.036291
#
#          86        87        88        89        90        91      92
# 0  0.173928  0.638205  0.538006  0.262535  0.239926  0.466438  0.0377
#
# [1 rows x 93 columns]

# %% [markdown]
# # Veamos ahora las curvas de degradación

# %%
def RUL_cycles(maquina):
    # el número del unitNumber se debe cambiar para visualizar el resto de máquinas en los datos de prueba.

    curva = list(gen_sequence(df_test1[df_test1['unitNumber'] == maquina], ventana, sequence_cols))
    len(curva)

    curva_array = np.concatenate(list(curva)).astype(np.float32)
    curva_array.shape

    curva_array = curva_array.reshape(len(curva), 50, 23)
    rul = model.predict(curva_array)
    plt.plot(rul[0:50])
    plt.xlabel('Ciclos')
    plt.ylabel('Indice de degradación (%)')
    
    x = np.asarray(list(range(len(curva))))
    return x, rul

# %%
x1, rul1 = RUL_cycles(15)
x2, rul2 = RUL_cycles(99)
x3, rul3 = RUL_cycles(41)
x4, rul4 = RUL_cycles(7)
x5, rul5 = RUL_cycles(74)
x6, rul6 = RUL_cycles(78)
x7, rul7 = RUL_cycles(77)
x8, rul8 = RUL_cycles(16)
x9, rul9 = RUL_cycles(18)
x10, rul10 = RUL_cycles(19)

rul1 = rul1.reshape(len(rul1))

x_new = np.linspace(rul1[0], 37, 1000)

from scipy.optimize import curve_fit

def exponenial_func(x, a, b, c):
    return a*np.exp(b*x)+c

popt, pcov = curve_fit(exponenial_func, x1, rul1, p0=(0.5, 0.5, 0.5))

plt.plot(x_new, popt[0]*np.exp(popt[1]*x_new)+popt[2], linewidth = 5)

# %%
popt
# Out:
# array([-0.00561298,  0.13873498,  0.749745  ])

# %%
x1, rul1 = RUL_cycles(15)

# %%
plt.plot(x_new, popt[0]*np.exp(popt[1]*x_new)+popt[2], linewidth = 5)
plt.xlabel('Ciclos')
plt.ylabel('Indice de degradación')
plt.ylim(0,0.8)
# Out:
# (0, 0.8)
